# %% [markdown]
# <a href="https://colab.research.google.com/github/Kelp710/vue_task/blob/main/Programming_Languages_(start).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# **Challenge**: Read the .csv file and store it in a Pandas dataframe

# %%
df = pd.read_csv("QueryResults.csv", names=['DATE', 'TAG', 'POSTS'], header=0)

# %%
df.DATE = pd.to_datetime(df.DATE)

# %%
df.head()
df.tail()
# Out:
#            DATE    TAG  POSTS
# 1986 2020-07-01      r   5694
# 1987 2020-07-01     go    743
# 1988 2020-07-01   ruby    775
# 1989 2020-07-01   perl    182
# 1990 2020-07-01  swift   3607

# %%
df.count()
# Out:
# DATE     1990
# TAG      1990
# POSTS    1990
# dtype: int64

# %%
df.shape
# Out:
# (1990, 3)

# %% [markdown]
# Calculate the total number of post per language.
# Which Programming language has had the highest total number of posts of all time?

# %%
df.groupby("TAG").sum()

# %% [markdown]
# Some languages are older (e.g., C) and other languages are newer (e.g., Swift). The dataset starts in September 2008.
# How many months of data exist per language? Which language had the fewest months with an entry?

# %%
df.groupby("TAG").count().sort_values("DATE", ascending=False)
# Out:
#             DATE  POSTS
# TAG
# c#           145    145
# assembly     144    144
# c            144    144
# c++          144    144
# delphi       144    144
# java         144    144
# javascript   144    144
# perl         144    144
# php          144    144
# python       144    144
# ruby         144    144
# r            142    142
# swift        135    135
# go           129    129

# %% [markdown]
# ## Data Cleaning
#
# Let's fix the date format to make it more readable. We need to use Pandas to change format from a string of "2008-07-01 00:00:00" to a datetime object with the format of "2008-07-01"

# %%
df["DATE"][1]
# Out:
# Timestamp('2008-08-01 00:00:00')

# %%
df.DATE[1]
# Out:
# Timestamp('2008-08-01 00:00:00')

# %%
type(pd.to_datetime(df["DATE"][1]))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## Data Manipulation

# %%
test_df = pd.DataFrame({'Age': ['Young', 'Young', 'Young', 'Young', 'Old', 'Old', 'Old', 'Old'],
                        'Actor': ['Jack', 'Arnold', 'Keanu', 'Sylvester', 'Jack', 'Arnold', 'Keanu', 'Sylvester'],
                        'Power': [100, 80, 25, 50, 99, 75, 5, 30]})

# %% [markdown]
# What are the dimensions of our new dataframe? How many rows and columns does it have? Print out the column names and print out the first 5 rows of the dataframe.

# %%
test_df.head()
# Out:
#      Age      Actor  Power
# 0  Young       Jack    100
# 1  Young     Arnold     80
# 2  Young      Keanu     25
# 3  Young  Sylvester     50
# 4    Old       Jack     99

# %%
pivot_df = test_df.pivot(index="Age", columns="Actor",values="Power")
pivot_df
# Out:
# Actor  Arnold  Jack  Keanu  Sylvester
# Age
# Old        75    99      5         30
# Young      80   100     25         50

# %%
df.DATE = pd.to_datetime(df.DATE)
reshaped_df=df.pivot(index="DATE", columns="TAG", values="POSTS")
reshaped_df
# Out:
# TAG         assembly       c       c#     c++  delphi     go     java  \
# DATE
# 2008-07-01       NaN     NaN      3.0     NaN     NaN    NaN      NaN
# 2008-08-01       8.0    85.0    511.0   164.0    14.0    NaN    222.0
# 2008-09-01      28.0   321.0   1649.0   755.0   105.0    NaN   1137.0
# 2008-10-01      15.0   303.0   1989.0   811.0   112.0    NaN   1153.0
# 2008-11-01      17.0   259.0   1730.0   735.0   141.0    NaN    958.0
# ...              ...     ...      ...     ...     ...    ...      ...
# 2020-03-01     317.0  2670.0   8954.0  5107.0   181.0  719.0  13253.0
# 2020-04-01     406.0  3472.0  10042.0  6820.0   250.0  887.0  15377.0
# 2020-05-01     386.0  3602.0   9923.0  7063.0   221.0  826.0  14711.0
# 2020-06-01     363.0  2757.0   9064.0  6161.0   214.0  765.0  13015.0
# 2020-07-01     298.0  2294.0   9145.0  5756.0   212.0  743.0  12723.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# DATE
# ...

# %% [markdown]
# **Challenge**: Count the number of entries per programming language. Why might the number of entries be different?

# %%
reshaped_df.count()
# Out:
# TAG
# assembly      144
# c             144
# c#            145
# c++           144
# delphi        144
# go            129
# java          144
# javascript    144
# perl          144
# php           144
# python        144
# r             142
# ruby          144
# swift         135
# dtype: int64

# %%
reshaped_df.fillna(0, inplace=True)

# %%
reshaped_df.isna().values.any()
# Out:
# False

# %% [markdown]
# ## Data Visualisaton with with Matplotlib

# %% [markdown]
# **Challenge**: Use the [matplotlib documentation](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) to plot a single programming language (e.g., java) on a chart.

# %%
plt.figure(figsize=(16,10))
plt.plot(reshaped_df.index, reshaped_df["java"])
plt.plot(reshaped_df.index, reshaped_df["python"])
plt.plot(reshaped_df.index, reshaped_df["javascript"])

# %%
plt.figure(figsize=(16,10))
for lang in reshaped_df.columns:
  plt.plot(reshaped_df.index, reshaped_df[lang], linewidth=3, label= reshaped_df[lang].name)
plt.legend(fontsize=16)

# %%
rolling_df = reshaped_df.rolling(window=5).mean()
plt.figure(figsize=(16,10))
for lang in rolling_df.columns:
  plt.plot(rolling_df.index, rolling_df[lang], linewidth=3, label= reshaped_df[lang].name)
plt.legend(fontsize=16)

# %%
roll_df = reshaped_df.rolling(window=6).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)

# plot the roll_df instead
for column in roll_df.columns:
    plt.plot(roll_df.index, roll_df[column], 
             linewidth=3, label=roll_df[column].name)

plt.legend(fontsize=16)
